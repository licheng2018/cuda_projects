# %% [markdown]
# # 📘 Task Explanation: CUDA Matrix Multiplication Optimization
# *(Naive → Block Tiling → Shared Memory)*
#
# This task guides you through a **three-day progressive implementation and optimization** of CUDA matrix multiplication (GEMM).
# You will start from a **naive implementation**, then introduce **block tiling**, and finally optimize using **shared memory with bank-conflict awareness**.
# The goal is to build a complete and systematic understanding of GPU optimization.
#
# ---
#
# ## 🗓️ Day 1 — Implement Naive MatMul Kernel & Test Correctness
#
# ### 🎯 Objective
# Implement the most straightforward CUDA matrix multiplication kernel to serve as a **performance baseline** for later optimizations, and ensure the result is correct.
#
# ### 🧩 Tasks
# - Write a naive CUDA kernel:
#   - Each thread computes one element of matrix `C`
#   - All operands are read directly from **global memory**
# - Implement a CPU reference version
# - Compare GPU results with CPU results to verify correctness
#
# ### 🧠 Key Concepts
# - Mapping 2D thread indices to matrix row/column indices
# - Understanding why the naive implementation repeatedly loads elements from `A` and `B`
# - Recognizing why this version is typically **memory-bound**
#
# ### 📦 Deliverables
# - Naive CUDA MatMul kernel
# - Correctness test (PASS / FAIL)
# - Baseline performance measurement
#
# ---
#
# ## 🗓️ Day 2 — Implement Block Tiling & Configure Tile Size
#
# ### 🎯 Objective
# Introduce **block-level tiling** so that threads within a block cooperate on computing a submatrix, laying the structural foundation for shared-memory optimization.
#
# ### 🧩 Tasks
# - Decompose matrices into fixed-size tiles (e.g., 16×16, 32×32)
# - Assign each thread block to compute one tile of matrix `C`
# - Use 2D block and thread indexing to map elements within a tile
# - Experiment with different tile sizes (16×16 vs 32×32)
#
# ### 🧠 Key Concepts
# - How tiling improves data locality
# - How tile size affects:
#   - Parallelism
#   - Occupancy
#   - Resource usage
# - Why block tiling alone does **not yet reduce global memory traffic**
#
# ### 📦 Deliverables
# - Block-tiled MatMul kernel
# - Performance comparison across different tile sizes
#
# ---
#
# ## 🗓️ Day 3 — Cache Tiles in Shared Memory & Handle Bank Conflicts
#
# ### 🎯 Objective
# Use **shared memory** to cache matrix tiles, reduce global memory accesses, and analyze and mitigate **shared-memory bank conflicts**.
#
# ### 🧩 Tasks
# - Load tiles of matrices `A` and `B` into shared memory
# - Synchronize threads within a block using `__syncthreads()`
# - Perform multiply–accumulate operations using shared memory
# - Analyze shared-memory access patterns
# - Identify and mitigate potential bank conflicts (e.g., via padding)
#
# ### 🧠 Key Concepts
# - How shared memory enables data reuse and reduces global memory traffic
# - How bank conflicts serialize shared-memory accesses and hurt performance
# - Why certain tile layouts naturally avoid bank conflicts
# - The role of padding in shared-memory layouts
#
# ### 📦 Deliverables
# - Shared-memory tiled MatMul kernel
# - Bank-conflict analysis and optimization notes
# - Performance comparison against naive and block-tiling versions
#
# ---
#
# ## 🎓 What You Should Learn from This Task
# By completing this task, you should understand:
# - The full optimization pipeline for CUDA GEMM
# - Why performance improves when moving from **global memory → shared memory**
# - Trade-offs between tile size and hardware resources
# - The real impact of bank conflicts on performance
#
# ---
#
# ## 🚀 Relevance to ML Systems
# Matrix multiplication is the computational core of:
# - cuBLAS GEMM
# - Linear and Attention layers in Transformers
# - Triton matmul kernels
# - Tensor Core–based acceleration
#
# Completing this task means you have built **GPU kernel engineer–level fundamentals** for ML systems and high-performance computing.

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Mon Jan 12 12:35:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !apt-get update
# !apt-get install -y cuda-toolkit-12-4

# %%
# %%writefile matmul_skeleton.cu
# #include <cstdio>
# #include <cstdlib>
# #include <cmath>
# #include <cuda_runtime.h>
#
#
# #define CUDA_CHECK(call) do {                                   \
#   cudaError_t err = (call);                                     \
#   if (err != cudaSuccess) {                                     \
#     fprintf(stderr, "CUDA error %s:%d: %s\n",                   \
#             __FILE__, __LINE__, cudaGetErrorString(err));       \
#     std::exit(EXIT_FAILURE);                                    \
#   }                                                             \
# } while(0)
#
# // -----------------------------
# // TODO: set TILE size (try 16 and 32)
# // -----------------------------
# #ifndef TILE16
# #define TILE16 16  // TODO
# #endif
#
# #ifndef TILE32
# #define TILE32 32  // TODO
# #endif
#
# // ============================================================
# // Day 1: Naive MatMul Kernel (Baseline)
# // C = A * B
# // A: MxK, B: KxN, C: MxN (row-major)
# // ============================================================
# __global__ void matmulNaive(const float* __restrict__ A,
#                             const float* __restrict__ B,
#                             float* __restrict__ C,
#                             int M, int N, int K) {
#     // TODO:
#     // - compute (row, col) from blockIdx/threadIdx
#     // - guard: if row < M && col < N
#     // - compute dot product over k in [0, K)
#     // - write C[row*N + col]
#
#     int row = blockIdx.y * TILE16 + threadIdx.y;
#     int col = blockIdx.x * TILE16 + threadIdx.x;
#
#     float acc = 0.0f;
#     if (row < M && col < N){
#         for (int k = 0; k < K; ++k){
#             acc += A[row * K + k] * B[k*N + col];
#         }
#         C[row * N + col] = acc;
#     }
# }
#
#
# // ============================================================
# // Day 2: Block Tiling Kernel (structure only, still global loads)
# // Each block computes one TILE x TILE output tile.
# // ============================================================
# __global__ void matmulBlockTiled(const float* __restrict__ A,
#                                  const float* __restrict__ B,
#                                  float* __restrict__ C,
#                                  int M, int N, int K) {
#     // TODO:
#     // - compute tile origin (blockRow, blockCol)
#     // - compute local (ty, tx) = threadIdx.y/x
#     // - compute global (row, col)
#     // - loop over k in [0, K) (still global reads)
#     // - write output
#
#     // Thread coordinates within the tile
#     int blockRow = blockIdx.y * TILE16;   // starting row of C tile
#     int blockCol = blockIdx.x * TILE16;   // starting col of C tile
#
#     //Global coordinates (row, col) for the output element computed by this thread
#     int row = blockRow + threadIdx.y;
#     int col = blockCol + threadIdx.x;
#
#     if (row >= M || col >= N)return;
#
#     float acc = 0.0f;
#
#     // K dimension tiling (still global loads)
#     #pragma unroll
#     for(int k_tile = 0; k_tile < K;  k_tile += TILE16){
#         for(int k_in_tile = 0; k_in_tile < TILE16; k_in_tile++){
#             int k = k_tile + k_in_tile;
#             if(k < K){
#                 acc += A[row * K + k] * B[k * N + col];
#             }
#         }
#
#     }
#     C[row * N + col] = acc;
# }
#
# // ============================================================
# // Day 3: Shared-Memory Tiled Kernel
# // Load A/B tiles into shared memory, synchronize, compute partial sums.
# // Also add a place to handle bank conflicts (e.g., padding) as TODO.
# // ============================================================
# __global__ void matmulSharedTiled(const float* __restrict__ A,
#                                   const float* __restrict__ B,
#                                   float* __restrict__ C,
#                                   int M, int N, int K) {
#     // TODO:
#     // - declare shared memory tiles for A and B
#     //   (optionally with padding for bank-conflict mitigation)
#     // - compute (row, col)
#     // - for each tile along K:
#     //     * load A tile element into shared (guarded)
#     //     * load B tile element into shared (guarded)
#     //     * __syncthreads()
#     //     * accumulate over tile dimension
#     //     * __syncthreads()
#     // - write C (guarded)
#
#     // Thread coordinates within the tile
#     int blockRow = blockIdx.y * TILE16;   // starting row of C tile
#     int blockCol = blockIdx.x * TILE16;   // starting col of C tile
#
#     //Global coordinates (row, col) for the output element computed by this thread
#     int row = blockRow + threadIdx.y;
#     int col = blockCol + threadIdx.x;
#
#     if (row >= M || col >= N)return;
#
#     __shared__ float As[TILE16][TILE16];
#     __shared__ float Bs[TILE16][TILE16];
#
#     float acc = 0.0f;
#
#     // ---- K-tiling loop ----
#     // t enumerates which K-tile we are processing
#     for(int k_tile = 0; k_tile < K;  k_tile += TILE16){
#         //load A tile elements(row, k_tile + tx)
#         int aRow = row;
#         int aCol = k_tile + threadIdx.x;
#         As[threadIdx.y][threadIdx.x] = (aRow < M && aCol < K)? A[aRow * K + aCol]:0.0f;
#
#         //load B tile elements(k_tile + ty, col)
#
#         int bRow = k_tile + threadIdx.y;
#         int bCol = col;
#         Bs[threadIdx.y][threadIdx.x] = (bRow < K && bCol < N)? B[bRow * N + bCol]:0.0f;
#
#         __syncthreads();
#
#
#         // Multiply-accumulate this K-tile
#         #pragma unroll
#         for(int kk = 0; kk < TILE16; kk++){
#             acc += As[threadIdx.y][kk] * Bs[kk][threadIdx.x];
#         }
#         __syncthreads();
#
#     }
#     if (row < M && col < N) {
#         C[row * N + col] = acc;
#         }
# }
#
# /*
# // ============================================================
# // Day 4: Shared-Memory Tiled Kernel
# // Load A/B tiles into shared memory, synchronize, compute partial sums.
# // TILE = 32, will cause bank conflict
# // ============================================================
# __global__ void matmulSharedTiled32(const float* __restrict__ A,
#                                   const float* __restrict__ B,
#                                   float* __restrict__ C,
#                                   int M, int N, int K) {
#     // TODO:
#     // - declare shared memory tiles for A and B
#     //   (optionally with padding for bank-conflict mitigation)
#     // - compute (row, col)
#     // - for each tile along K:
#     //     * load A tile element into shared (guarded)
#     //     * load B tile element into shared (guarded)
#     //     * __syncthreads()
#     //     * accumulate over tile dimension
#     //     * __syncthreads()
#     // - write C (guarded)
#
#     // Thread coordinates within the tile
#     int blockRow = blockIdx.y * TILE32;   // starting row of C tile
#     int blockCol = blockIdx.x * TILE32;   // starting col of C tile
#
#     //Global coordinates (row, col) for the output element computed by this thread
#     int row = blockRow + threadIdx.y;
#     int col = blockCol + threadIdx.x;
#
#     if (row >= M || col >= N)return;
#
#     __shared__ float As[TILE32][TILE32];
#     __shared__ float Bs[TILE32][TILE32];
#
#     float acc = 0.0f;
#
#     // ---- K-tiling loop ----
#     // t enumerates which K-tile we are processing
#     for(int k_tile = 0; k_tile < K;  k_tile += TILE32){
#         //load A tile elements(row, k_tile + tx)
#         int aRow = row;
#         int aCol = k_tile + threadIdx.x;
#         As[threadIdx.y][threadIdx.x] = (aRow < M && aCol < K)? A[aRow * K + aCol]:0.0f;
#
#         //load B tile elements(k_tile + ty, col)
#
#         int bRow = k_tile + threadIdx.y;
#         int bCol = col;
#         Bs[threadIdx.y][threadIdx.x] = (bRow < K && bCol < N)? B[bRow * N + bCol]:0.0f;
#
#         __syncthreads();
#
#
#         // Multiply-accumulate this K-tile
#         #pragma unroll
#         for(int kk = 0; kk < TILE32; kk++){
#             acc += As[threadIdx.y][kk] * Bs[kk][threadIdx.x];
#         }
#         __syncthreads();
#
#     }
#     if (row < M && col < N) {
#         C[row * N + col] = acc;
#         }
# }
# */
# // ============================================================
# // Day 4: Shared-Memory Tiled Kernel
# // Load A/B tiles into shared memory, synchronize, compute partial sums.
# // TILE = 32, will cause bank conflict
# // ============================================================
# __global__ void matmulSharedTiled32(const float* __restrict__ A,
#                                              const float* __restrict__ B,
#                                              float* __restrict__ C,
#                                              int M, int N, int K) {
#     const int TILE = 32;
#
#     int row = blockIdx.y * TILE + threadIdx.y;
#     int col = blockIdx.x * TILE + threadIdx.x;
#     if (row >= M || col >= N) return;
#
#     __shared__ float As[TILE][TILE];
#     __shared__ float BsT[TILE][TILE];
#
#     float acc = 0.0f;
#
#     for (int k_tile = 0; k_tile < K; k_tile += TILE) {
#         // A tile
#         int aCol = k_tile + threadIdx.x;
#         As[threadIdx.y][threadIdx.x] =
#             (aCol < K) ? A[row * K + aCol] : 0.0f;
#
#         // B tile -> transpose store
#         int bRow = k_tile + threadIdx.y;
#         float bval = (bRow < K) ? B[bRow * N + col] : 0.0f;
#         BsT[threadIdx.x][threadIdx.y] = bval;   // transpose
#
#         __syncthreads();
#
#         // 关键：按“列”读 BsT → stride=32 → 32-way bank conflict
#         #pragma unroll
#         for (int kk = 0; kk < TILE; ++kk) {
#             acc += As[threadIdx.y][kk] * BsT[threadIdx.x][kk];
#         }
#         //for(int kk = 0; kk < TILE32; kk++){
#         //     acc += As[threadIdx.y][kk] * Bs[kk][threadIdx.x];
#         //}
#
#         __syncthreads();
#     }
#
#     C[row * N + col] = acc;
# }
#
# /*
# // ============================================================
# // Day 4: Shared-Memory Tiled Kernel
# // Load A/B tiles into shared memory, synchronize, compute partial sums.
# // TILE = 32, will cause bank conflict
# // ============================================================
# __global__ void matmulSharedTiled32(const float* __restrict__ A,
#                                    const float* __restrict__ B,
#                                    float* __restrict__ C,
#                                    int M, int N, int K)
# {
#     // --------------------------------------------------------
#     // Thread coordinates within the tile
#     // --------------------------------------------------------
#     int blockRow = blockIdx.y * TILE32;   // starting row of C tile
#     int blockCol = blockIdx.x * TILE32;   // starting col of C tile
#
#     // Global coordinates (row, col)
#     int row = blockRow + threadIdx.y;
#     int col = blockCol + threadIdx.x;
#
#     if (row >= M || col >= N) return;
#
#     // --------------------------------------------------------
#     // Shared memory tiles (NO padding → bank conflict)
#     // --------------------------------------------------------
#     __shared__ float As[TILE32][TILE32];
#     __shared__ float Bs[TILE32][TILE32];
#
#     float acc = 0.0f;
#
#     // --------------------------------------------------------
#     // K-tiling loop
#     // --------------------------------------------------------
#     for (int k_tile = 0; k_tile < K; k_tile += TILE32) {
#
#         // ---- Load A tile: A[row][k_tile + tx] ----
#         int aRow = row;
#         int aCol = k_tile + threadIdx.x;
#         As[threadIdx.y][threadIdx.x] =
#             (aRow < M && aCol < K) ? A[aRow * K + aCol] : 0.0f;
#
#         // ---- Load B tile: B[k_tile + ty][col] ----
#         int bRow = k_tile + threadIdx.y;
#         int bCol = col;
#         Bs[threadIdx.y][threadIdx.x] =
#             (bRow < K && bCol < N) ? B[bRow * N + bCol] : 0.0f;
#
#         __syncthreads();
#
#         // ---- Multiply-accumulate ----
#         #pragma unroll
#         for (int kk = 0; kk < TILE32; kk++) {
#             acc += As[threadIdx.y][kk] * Bs[kk][threadIdx.x];
#         }
#
#         __syncthreads();
#     }
#
#     // --------------------------------------------------------
#     // Write result
#     // --------------------------------------------------------
#     C[row * N + col] = acc;
# }
#
# */
#
# // ============================================================
# // Day 5: Shared-Memory Tiled Kernel
# // Load A/B tiles into shared memory, synchronize, compute partial sums.
# // TILE = 32, will cause bank conflict
# // padding will be apply to avoid this
# // ============================================================
# /*
# __global__ void matmulSharedTiled32padding(const float* __restrict__ A,
#                                   const float* __restrict__ B,
#                                   float* __restrict__ C,
#                                   int M, int N, int K) {
#     // TODO:
#     // - declare shared memory tiles for A and B
#     //   (optionally with padding for bank-conflict mitigation)
#     // - compute (row, col)
#     // - for each tile along K:
#     //     * load A tile element into shared (guarded)
#     //     * load B tile element into shared (guarded)
#     //     * __syncthreads()
#     //     * accumulate over tile dimension
#     //     * __syncthreads()
#     // - write C (guarded)
#
#     // Thread coordinates within the tile
#
#     const int PADDED_PITCH = TILE32 + 1;
#     int blockRow = blockIdx.y * (TILE32);   // starting row of C tile
#     int blockCol = blockIdx.x * (TILE32);   // starting col of C tile
#
#     //Global coordinates (row, col) for the output element computed by this thread
#     int row = blockRow + threadIdx.y;
#     int col = blockCol + threadIdx.x;
#
#     if (row >= M || col >= N)return;
#
#     __shared__ float As[TILE32][PADDED_PITCH];
#     __shared__ float Bs[TILE32][PADDED_PITCH];
#
#     float acc = 0.0f;
#
#     // ---- K-tiling loop ----
#     // t enumerates which K-tile we are processing
#     for(int k_tile = 0; k_tile < K;  k_tile += TILE32){
#         //load A tile elements(row, k_tile + tx)
#         int aRow = row;
#         int aCol = k_tile + threadIdx.x;
#         As[threadIdx.y][threadIdx.x] = (aRow < M && aCol < K)? A[aRow * K + aCol]:0.0f;
#
#         //load B tile elements(k_tile + ty, col)
#
#         int bRow = k_tile + threadIdx.y;
#         int bCol = col;
#         Bs[threadIdx.y][threadIdx.x] = (bRow < K && bCol < N)? B[bRow * N + bCol]:0.0f;
#
#         __syncthreads();
#
#
#         // Multiply-accumulate this K-tile
#         #pragma unroll
#         for(int kk = 0; kk < TILE32; kk++){
#             acc += As[threadIdx.y][kk] * Bs[kk][threadIdx.x];
#         }
#         __syncthreads();
#
#     }
#     if (row < M && col < N) {
#         C[row * N + col] = acc;
#         }
# }
# */
#
# __global__ void matmulSharedTiled32padding(const float* __restrict__ A,
#                                            const float* __restrict__ B,
#                                            float* __restrict__ C,
#                                            int M, int N, int K) {
#     const int TILE = 32;
#
#     int row = blockIdx.y * TILE + threadIdx.y;
#     int col = blockIdx.x * TILE + threadIdx.x;
#     if (row >= M || col >= N) return;
#
#     __shared__ float As[TILE][TILE];
#     __shared__ float BsT[TILE][TILE + 1];  // pitch=33（关键：+1）
#
#     float acc = 0.0f;
#
#     for (int k_tile = 0; k_tile < K; k_tile += TILE) {
#         int aCol = k_tile + threadIdx.x;
#         As[threadIdx.y][threadIdx.x] =
#             (aCol < K) ? A[row * K + aCol] : 0.0f;
#
#         int bRow = k_tile + threadIdx.y;
#         float bval = (bRow < K) ? B[bRow * N + col] : 0.0f;
#         BsT[threadIdx.x][threadIdx.y] = bval;   // transpose
#
#         __syncthreads();
#
#         // 同样按列读，但 pitch=33 → bank 映射被打散
#         #pragma unroll
#         for (int kk = 0; kk < TILE; ++kk) {
#             acc += As[threadIdx.y][kk] * BsT[threadIdx.x][kk];
#         }
#
#         __syncthreads();
#     }
#
#     C[row * N + col] = acc;
# }
#
# // ============================================================
# // CPU reference GEMM (correctness baseline)
# // ============================================================
# static void matmulCPU(const float* A, const float* B, float* C, int M, int N, int K) {
#
#     double acc = 0.0;
#     for (int i = 0; i < M; ++i) {
#         for (int j = 0; j < N; ++j) {
#             acc = 0.0;
#             for (int k = 0; k < K; ++k) {
#                 acc += (double)A[i * K + k] * (double)B[k * N + j];
#             }
#             C[i * N + j] = (float)acc;
#         }
#     }
# }
#
# // ============================================================
# // TODO: correctness checker
# // Requirements:
# //  - compare gpu vs ref within tol
# //  - print first mismatch (i, gpu, ref)
# // ============================================================
# static bool checkClose(const float* gpu, const float* ref, int count, float tol) {
#     // TODO
#     for (int i = 0; i < count; ++i){
#         if (fabsf(gpu[i] - ref[i]) >  tol){
#             printf("mismatch in %d digit, cpu is %.2f, gpu is %.2f\n", i, ref[i], gpu[i]);
#
#             return false;
#         }
#     }
#     return true;
# }
#
# // ============================================================
# // Timing helper (CUDA events) - implemented
# // ============================================================
# template <typename KernelFunc>
# static float timeKernelMs(KernelFunc kernel,
#                           dim3 grid, dim3 block,
#                           const float* dA, const float* dB, float* dC,
#                           int M, int N, int K,
#                           int warmup, int iters) {
#     for (int i = 0; i < warmup; ++i) {
#         kernel<<<grid, block>>>(dA, dB, dC, M, N, K);
#     }
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#
#     cudaEvent_t start, stop;
#     CUDA_CHECK(cudaEventCreate(&start));
#     CUDA_CHECK(cudaEventCreate(&stop));
#
#     CUDA_CHECK(cudaEventRecord(start));
#     for (int i = 0; i < iters; ++i) {
#         kernel<<<grid, block>>>(dA, dB, dC, M, N, K);
#     }
#     CUDA_CHECK(cudaEventRecord(stop));
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaEventSynchronize(stop));
#
#     float ms = 0.0f;
#     CUDA_CHECK(cudaEventElapsedTime(&ms, start, stop));
#     CUDA_CHECK(cudaEventDestroy(start));
#     CUDA_CHECK(cudaEventDestroy(stop));
#
#     return ms / iters;
# }
#
# // ============================================================
# // TODO (optional): GFLOPS estimator
# // FLOPs ≈ 2*M*N*K
# // ============================================================
# static double estimateGFLOPS(int M, int N, int K, float ms) {
#     // TODO
#     double flops = 2.0 * (double)M * (double)N * (double)K;   // mul+add
#     double gflops = flops / (ms * 1e-3) / 1e9;
#     return gflops;
# }
#
# int main() {
#     // Sizes (try non-multiples of TILE to test boundary guards)
#     const int M = 1024;
#     const int N = 1024;
#     const int K = 1024;
#
#     // Tolerance (float accumulation)
#     const float tol = 1e-3f; // TODO (e.g., 1e-3 or 1e-2)
#
#     const size_t bytesA = size_t(M) * K * sizeof(float);
#     const size_t bytesB = size_t(K) * N * sizeof(float);
#     const size_t bytesC = size_t(M) * N * sizeof(float);
#
#     // Host alloc
#     float* hA = (float*)std::malloc(bytesA);
#     float* hB = (float*)std::malloc(bytesB);
#     float* hC_ref = (float*)std::malloc(bytesC);
#     float* hC_gpu = (float*)std::malloc(bytesC);
#
#     if (!hA || !hB || !hC_ref || !hC_gpu) {
#         fprintf(stderr, "Host malloc failed.\n");
#         return EXIT_FAILURE;
#     }
#
#     // Init
#     for (int i = 0; i < M * K; ++i) hA[i] = 0.001f * (i % 1000);
#     for (int i = 0; i < K * N; ++i) hB[i] = 0.002f * (i % 1000);
#
#     // CPU reference
#     matmulCPU(hA, hB, hC_ref, M, N, K);
#
#     // Device alloc
#     float *dA=nullptr, *dB=nullptr, *dC=nullptr;
#     CUDA_CHECK(cudaMalloc(&dA, bytesA));
#     CUDA_CHECK(cudaMalloc(&dB, bytesB));
#     CUDA_CHECK(cudaMalloc(&dC, bytesC));
#     CUDA_CHECK(cudaMemcpy(dA, hA, bytesA, cudaMemcpyHostToDevice));
#     CUDA_CHECK(cudaMemcpy(dB, hB, bytesB, cudaMemcpyHostToDevice));
#
#     // ------------------------------------------------------------
#     // TODO: choose block/grid for 2D kernels
#     // Typical:
#     //   block = (TILE, TILE)
#     //   grid  = (ceil(N/TILE), ceil(M/TILE))
#     // ------------------------------------------------------------
#
#     dim3 block16(TILE16, TILE16, 1); // TODO
#     dim3 grid16((N + TILE16 - 1)/TILE16, (M + TILE16 - 1)/TILE16, 1);  // TODO
#     dim3 block32(TILE32, TILE32, 1); // TODO
#     dim3 grid32((N + TILE32 - 1)/(TILE32), (M + TILE32- 1)/(TILE32), 1);  // TODO
#
#     // ------------------------------------------------------------
#     // TODO: Choose which kernel to run:
#     //  - Day1: matmulNaive
#     //  - Day2: matmulBlockTiled
#     //  - Day3: matmulSharedTiled
#     // ------------------------------------------------------------
#     /*
#     int which = 2; // TODO: 1/2/3
#
#     // Launch for correctness + timing
#     if (which == 1) {
#         matmulNaive<<<grid, block>>>(dA, dB, dC, M, N, K);
#     } else if (which == 2) {
#         matmulBlockTiled<<<grid, block>>>(dA, dB, dC, M, N, K);
#     } else {
#         matmulSharedTiled<<<grid, block>>>(dA, dB, dC, M, N, K);
#     }
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#
#     CUDA_CHECK(cudaMemcpy(hC_gpu, dC, bytesC, cudaMemcpyDeviceToHost));
#
#     // Correctness
#     bool ok = checkClose(hC_gpu, hC_ref, M * N, tol);
#     printf("Correctness: %s\n", ok ? "PASS" : "FAIL");
#     */
#
#     // Timing
#     const int warmup = 5;
#     const int iters = 20;
#     float ms = 0.0f;
#
#     /*
#     if (which == 1) {
#         ms = timeKernelMs(matmulNaive, grid, block, dA, dB, dC, M, N, K, warmup, iters);
#     } else if (which == 2) {
#         ms = timeKernelMs(matmulBlockTiled, grid, block, dA, dB, dC, M, N, K, warmup, iters);
#     } else {
#         ms = timeKernelMs(matmulSharedTiled, grid, block, dA, dB, dC, M, N, K, warmup, iters);
#     }*/
#
#
#     matmulNaive<<<grid16, block16>>>(dA, dB, dC, M, N, K);
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#     CUDA_CHECK(cudaMemcpy(hC_gpu, dC, bytesC, cudaMemcpyDeviceToHost));
#     bool ok = checkClose(hC_gpu, hC_ref, M * N, tol);
#     ms = timeKernelMs(matmulNaive, grid16, block16, dA, dB, dC, M, N, K, warmup, iters);
#     double gflops = estimateGFLOPS(M, N, K, ms);
#     printf("[Naive MatMul Kernel (Baseline)]                          Kernel=%d | correctness = %s | time=%.4f ms | GFLOPS=%.2f\n", 1, ok? "PASS" : "FAIL", ms, gflops);
#
#
#     matmulBlockTiled<<<grid16, block16>>>(dA, dB, dC, M, N, K);
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#     CUDA_CHECK(cudaMemcpy(hC_gpu, dC, bytesC, cudaMemcpyDeviceToHost));
#     ok = checkClose(hC_gpu, hC_ref, M * N, tol);
#     ms = timeKernelMs(matmulBlockTiled, grid16, block16, dA, dB, dC, M, N, K, warmup, iters);
#     gflops = estimateGFLOPS(M, N, K, ms);
#     printf("[Block Tiling Kernel (structure only, still global loads)]Kernel=%d | correctness = %s | time=%.4f ms | GFLOPS=%.2f\n",  2, ok? "PASS" : "FAIL", ms, gflops);
#
#     matmulSharedTiled<<<grid16, block16>>>(dA, dB, dC, M, N, K);
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#     CUDA_CHECK(cudaMemcpy(hC_gpu, dC, bytesC, cudaMemcpyDeviceToHost));
#     ok = checkClose(hC_gpu, hC_ref, M * N, tol);
#     ms = timeKernelMs(matmulSharedTiled, grid16, block16, dA, dB, dC, M, N, K, warmup, iters);
#     gflops = estimateGFLOPS(M, N, K, ms);
#     printf("[Shared-Memory Tiled Kernel(Tile16)]                    Kernel=%d | correctness = %s | time=%.4f ms | GFLOPS=%.2f\n", 3, ok? "PASS" : "FAIL", ms, gflops);
#
#
#
#
#     matmulSharedTiled32<<<grid32, block32>>>(dA, dB, dC, M, N, K);
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#     CUDA_CHECK(cudaMemcpy(hC_gpu, dC, bytesC, cudaMemcpyDeviceToHost));
#     ok = checkClose(hC_gpu, hC_ref, M * N, tol);
#     ms = timeKernelMs(matmulSharedTiled32, grid32, block32, dA, dB, dC, M, N, K, warmup, iters);
#     gflops = estimateGFLOPS(M, N, K, ms);
#     printf("[Shared-Memory Tiled Kernel(Tile32)]                   Kernel=%d | correctness = %s | time=%.4f ms | GFLOPS=%.2f\n", 4, ok? "PASS" : "FAIL", ms, gflops);
#
#
#     matmulSharedTiled32padding<<<grid32, block32>>>(dA, dB, dC, M, N, K);
#     CUDA_CHECK(cudaGetLastError());
#     CUDA_CHECK(cudaDeviceSynchronize());
#     CUDA_CHECK(cudaMemcpy(hC_gpu, dC, bytesC, cudaMemcpyDeviceToHost));
#     ok = checkClose(hC_gpu, hC_ref, M * N, tol);
#     ms = timeKernelMs(matmulSharedTiled32padding, grid32, block32, dA, dB, dC, M, N, K, warmup, iters);
#     gflops = estimateGFLOPS(M, N, K, ms);
#     printf("[Shared-Memory Tiled Kernel(Tile32padding)]            Kernel=%d | correctness = %s | time=%.4f ms | GFLOPS=%.2f\n", 5, ok? "PASS" : "FAIL", ms, gflops);
#
#
#     // Cleanup
#     CUDA_CHECK(cudaFree(dA));
#     CUDA_CHECK(cudaFree(dB));
#     CUDA_CHECK(cudaFree(dC));
#     std::free(hA);
#     std::free(hB);
#     std::free(hC_ref);
#     std::free(hC_gpu);
#
#     return ok ? EXIT_SUCCESS : EXIT_FAILURE;
# }
# Out:
# Overwriting matmul_skeleton.cu

# %%
# !nvcc -arch=sm_75 matmul_skeleton.cu -o matmul_skeleton
# !./matmul_skeleton
# Out:
# [Naive MatMul Kernel (Baseline)]                          Kernel=1 | correctness = PASS | time=9.1753 ms | GFLOPS=234.05
# [Block Tiling Kernel (structure only, still global loads)]Kernel=2 | correctness = PASS | time=4.0592 ms | GFLOPS=529.04
# [Shared-Memory Tiled Kernel(Tile16)]                    Kernel=3 | correctness = PASS | time=2.4577 ms | GFLOPS=873.76
# [Shared-Memory Tiled Kernel(Tile32)]                   Kernel=4 | correctness = PASS | time=10.4073 ms | GFLOPS=206.34
# [Shared-Memory Tiled Kernel(Tile32padding)]            Kernel=5 | correctness = PASS | time=2.0924 ms | GFLOPS=1026.32

# %%
# !ncu --section "MemoryWorkloadAnalysis" --section "SourceCounters" ./matmul_skeleton
# Out:
# ==PROF== Connected to process 16077 (/content/matmul_skeleton)
# ==PROF== Profiling "matmulNaive" - 0: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 1: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 2: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 3: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 4: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 5: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 6: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 7: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 8: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 9: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 10: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 11: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 12: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 13: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 14: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 15: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 16: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 17: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 18: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 19: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 20: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 21: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 22: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 23: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 24: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulNaive" - 25: 0%....50%....100% - 12 passes
# [Naive MatMul Kernel (Baseline)]                          Kernel=1 | correctness = PASS | time=896.6193 ms | GFLOPS=2.40
# ==PROF== Profiling "matmulBlockTiled" - 26: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 27: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 28: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 29: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 30: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 31: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 32: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 33: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 34: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 35: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 36: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 37: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 38: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 39: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 40: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 41: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 42: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 43: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 44: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 45: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 46: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 47: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 48: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 49: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 50: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulBlockTiled" - 51: 0%....50%....100% - 12 passes
# [Block Tiling Kernel (structure only, still global loads)]Kernel=2 | correctness = PASS | time=1431.8516 ms | GFLOPS=1.50
# ==PROF== Profiling "matmulSharedTiled" - 52: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 53: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 54: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 55: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 56: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 57: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 58: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 59: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 60: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 61: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 62: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 63: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 64: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 65: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 66: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 67: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 68: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 69: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 70: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 71: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 72: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 73: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 74: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 75: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 76: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled" - 77: 0%....50%....100% - 12 passes
# [Shared-Memory Tiled Kernel(Tile16)]                    Kernel=3 | correctness = PASS | time=692.7777 ms | GFLOPS=3.10
# ==PROF== Profiling "matmulSharedTiled32" - 78: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 79: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 80: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 81: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 82: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 83: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 84: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 85: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 86: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 87: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 88: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 89: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 90: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 91: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 92: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 93: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 94: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 95: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 96: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 97: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 98: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 99: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 100: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 101: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 102: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32" - 103: 0%....50%....100% - 12 passes
# [Shared-Memory Tiled Kernel(Tile32)]                   Kernel=4 | correctness = PASS | time=747.0571 ms | GFLOPS=2.87
# ==PROF== Profiling "matmulSharedTiled32padding" - 104: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 105: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 106: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 107: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 108: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 109: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 110: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 111: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 112: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 113: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 114: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 115: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 116: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 117: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 118: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 119: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 120: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 121: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 122: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 123: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 124: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 125: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 126: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 127: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 128: 0%....50%....100% - 12 passes
# ==PROF== Profiling "matmulSharedTiled32padding" - 129: 0%....50%....100% - 12 passes
# [Shared-Memory Tiled Kernel(Tile32padding)]            Kernel=5 | correctness = PASS | time=730.1800 ms | GFLOPS=2.94
# ==PROF== Disconnected from process 16077
# [16077] matmul_skeleton@127.0.0.1
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.15
#     Mem Busy                    %        46.88
#     Max Bandwidth               %        62.50
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.09
#     Mem Pipes Busy              %        62.50
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.28
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.52
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.04
#     Mem Pipes Busy              %        62.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.19
#     Mem Busy                    %        46.93
#     Max Bandwidth               %        62.57
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.09
#     Mem Pipes Busy              %        62.57
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.29
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.12
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.31
#     Mem Busy                    %        46.88
#     Max Bandwidth               %        62.50
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.13
#     Mem Pipes Busy              %        62.50
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.20
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.54
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.15
#     Mem Pipes Busy              %        62.54
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.35
#     Mem Busy                    %        46.88
#     Max Bandwidth               %        62.51
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.05
#     Mem Pipes Busy              %        62.51
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.23
#     Mem Busy                    %        47.01
#     Max Bandwidth               %        62.67
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.03
#     Mem Pipes Busy              %        62.67
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.28
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.10
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.24
#     Mem Busy                    %        46.92
#     Max Bandwidth               %        62.55
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.07
#     Mem Pipes Busy              %        62.55
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.29
#     Mem Busy                    %        46.89
#     Max Bandwidth               %        62.52
#     L1/TEX Hit Rate             %        87.38
#     L2 Hit Rate                 %        82.07
#     Mem Pipes Busy              %        62.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.23
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.52
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.22
#     Mem Pipes Busy              %        62.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.18
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.08
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.24
#     Mem Busy                    %        47.03
#     Max Bandwidth               %        62.69
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.03
#     Mem Pipes Busy              %        62.69
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.27
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.54
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.15
#     Mem Pipes Busy              %        62.54
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.32
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.06
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.17
#     Mem Busy                    %        46.89
#     Max Bandwidth               %        62.52
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.10
#     Mem Pipes Busy              %        62.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.25
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.05
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.25
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.04
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.21
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.12
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.22
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.09
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.26
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.55
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.11
#     Mem Pipes Busy              %        62.55
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.22
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.52
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.14
#     Mem Pipes Busy              %        62.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.20
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.52
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.04
#     Mem Pipes Busy              %        62.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.24
#     Mem Busy                    %        46.90
#     Max Bandwidth               %        62.53
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.10
#     Mem Pipes Busy              %        62.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulNaive(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        22.34
#     Mem Busy                    %        46.91
#     Max Bandwidth               %        62.55
#     L1/TEX Hit Rate             %        87.37
#     L2 Hit Rate                 %        82.10
#     Mem Pipes Busy              %        62.55
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.02
#     Branch Instructions              inst    2,392,064
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.87
#     Mem Busy                    %        47.10
#     Max Bandwidth               %        62.79
#     L1/TEX Hit Rate             %        87.31
#     L2 Hit Rate                 %        83.37
#     Mem Pipes Busy              %        62.79
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.98
#     Mem Busy                    %        47.08
#     Max Bandwidth               %        62.77
#     L1/TEX Hit Rate             %        87.32
#     L2 Hit Rate                 %        83.48
#     Mem Pipes Busy              %        62.77
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.93
#     Mem Busy                    %        47.10
#     Max Bandwidth               %        62.79
#     L1/TEX Hit Rate             %        87.31
#     L2 Hit Rate                 %        83.35
#     Mem Pipes Busy              %        62.79
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.99
#     Mem Busy                    %        47.07
#     Max Bandwidth               %        62.75
#     L1/TEX Hit Rate             %        87.32
#     L2 Hit Rate                 %        83.38
#     Mem Pipes Busy              %        62.75
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.61
#     Mem Busy                    %        47.10
#     Max Bandwidth               %        62.80
#     L1/TEX Hit Rate             %        87.32
#     L2 Hit Rate                 %        83.38
#     Mem Pipes Busy              %        62.80
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        21.10
#     Mem Busy                    %        47.08
#     Max Bandwidth               %        62.77
#     L1/TEX Hit Rate             %        87.32
#     L2 Hit Rate                 %        83.51
#     Mem Pipes Busy              %        62.77
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.83
#     Mem Busy                    %        47.10
#     Max Bandwidth               %        62.80
#     L1/TEX Hit Rate             %        87.32
#     L2 Hit Rate                 %        83.44
#     Mem Pipes Busy              %        62.80
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    2,195,456
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulBlockTiled(const float *, const float *, float *, int, int, int) (64, 64, 1)x(16, 16, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        20.94
#     Mem Busy                    %        47.07
#     Max Bandwidth               %        62.76
#     L1/TEX Hit Rate             %        87.32
#     L2 Hit Rate                 %        83.47
#     Mem Pipes Busy              %        62.76
#     ----------------- ----------- ------------
#
#     Section: Source Counters
# ...
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.14
#     Mem Busy                    %        44.18
#     Max Bandwidth               %        74.52
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.59
#     Mem Pipes Busy              %        74.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.08
#     Mem Busy                    %        44.16
#     Max Bandwidth               %        74.49
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.58
#     Mem Pipes Busy              %        74.49
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.08
#     Mem Busy                    %        44.21
#     Max Bandwidth               %        74.57
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.61
#     Mem Pipes Busy              %        74.57
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.10
#     Mem Busy                    %        44.15
#     Max Bandwidth               %        74.47
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.57
#     Mem Pipes Busy              %        74.47
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.14
#     Mem Busy                    %        44.19
#     Max Bandwidth               %        74.53
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.51
#     Mem Pipes Busy              %        74.53
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.08
#     Mem Busy                    %        44.17
#     Max Bandwidth               %        74.51
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.57
#     Mem Pipes Busy              %        74.51
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.11
#     Mem Busy                    %        44.17
#     Max Bandwidth               %        74.51
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.61
#     Mem Pipes Busy              %        74.51
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.10
#     Mem Busy                    %        44.18
#     Max Bandwidth               %        74.52
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.55
#     Mem Pipes Busy              %        74.52
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.13
#     Mem Busy                    %        44.19
#     Max Bandwidth               %        74.54
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.57
#     Mem Pipes Busy              %        74.54
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.16
#     Mem Busy                    %        44.21
#     Max Bandwidth               %        74.57
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.58
#     Mem Pipes Busy              %        74.57
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.15
#     Mem Busy                    %        44.20
#     Max Bandwidth               %        74.56
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.54
#     Mem Pipes Busy              %        74.56
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.09
#     Mem Busy                    %        44.17
#     Max Bandwidth               %        74.50
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.56
#     Mem Pipes Busy              %        74.50
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.15
#     Mem Busy                    %        44.17
#     Max Bandwidth               %        74.51
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.60
#     Mem Pipes Busy              %        74.51
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
#
#   matmulSharedTiled32padding(const float *, const float *, float *, int, int, int) (32, 32, 1)x(32, 32, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: Memory Workload Analysis
#     ----------------- ----------- ------------
#     Metric Name       Metric Unit Metric Value
#     ----------------- ----------- ------------
#     Memory Throughput     Gbyte/s        27.15
#     Mem Busy                    %        44.15
#     Max Bandwidth               %        74.48
#     L1/TEX Hit Rate             %            0
#     L2 Hit Rate                 %        63.58
#     Mem Pipes Busy              %        74.48
#     ----------------- ----------- ------------
#
#     Section: Source Counters
#     ------------------------- ----------- ------------
#     Metric Name               Metric Unit Metric Value
#     ------------------------- ----------- ------------
#     Branch Instructions Ratio           %         0.01
#     Branch Instructions              inst    1,146,880
#     Branch Efficiency                   %          100
#     Avg. Divergent Branches                          0
#     ------------------------- ----------- ------------
